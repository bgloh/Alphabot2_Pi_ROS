# %%
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# C:\Users\User\Desktop\YOLO5\capstone\yolov5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
# ...

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5  v6.1-233-g7433d38 Python-3.8.13 torch-1.11.0+cpu CPU
# Setup complete  (16 CPUs, 31.7 GB RAM, 284.3/475.8 GB disk)

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: F8DB-A07C
#
#  C:\Users\User\Desktop\YOLO5\capstone\yolov5 디렉터리
#
# 2022-05-29  오전 03:05    <DIR>          .
# 2022-05-29  오전 03:06    <DIR>          ..
# 2022-05-29  오전 02:49                77 .gitattributes
# 2022-05-29  오전 02:49    <DIR>          .github
# 2022-05-29  오전 02:49             4,238 .gitignore
# 2022-05-29  오전 02:49             1,651 .pre-commit-config.yaml
# 2022-05-29  오전 02:49             5,062 CONTRIBUTING.md
# 2022-05-29  오전 03:04    <DIR>          data
# 2022-05-29  오전 02:49            13,548 detect.py
# 2022-05-29  오전 02:49            30,530 export.py
# 2022-05-29  오전 02:49             6,611 hubconf.py
# 2022-05-29  오전 02:49            35,801 LICENSE
# 2022-05-29  오전 02:49    <DIR>          models
# 2022-05-29  오전 02:49            16,147 README.md
# 2022-05-29  오전 02:49             1,072 requirements.txt
# 2022-05-29  오전 02:49             1,790 setup.cfg
# 2022-05-29  오전 02:49            35,609 train.py
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data data/custom_data.yaml --weights yolov5x.pt --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=data/custom_data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v6.1-233-g7433d38 Python-3.8.13 torch-1.11.0+cpu CPU
#
# ...

# %%
python train.py --img 640 --batch 16 --epochs 300 --data data/custom_data.yaml --weights yolov5x.pt --cache
